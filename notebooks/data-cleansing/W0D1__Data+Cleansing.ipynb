# %% [markdown]
# # <center> **Data Cleansing**
#
# ---
#
# > A process of detecting and rectifying (or deleting) of untrustworthy, inaccurate or outdated information from a data set, archives, table, or database. It helps you to identify incomplete, incorrect, inaccurate or irrelevant parts of the data.
#
# > When combining multiple data sources, there are many opportunities for data to be duplicated or mislabeled. If data is incorrect, outcomes and algorithms are unreliable, even though they may look correct.

# %% [markdown]
# ***
#
# ## <center> Today's Problem
#
# ---
#
# <center><img src="logo.png"></center>
#
# ---
#
# <center><img src="Metadata.png"></center>

# %%
# 10k samples from SF DBI permits record
import pandas as pd
df = pd.read_csv("Sample10k_Building_Permits.csv", sep=',', header=0)
df.shape
# Out:
# (10000, 43)

# %%
df.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0       M766848            8            otc alterations permit
# 1       M762447            8            otc alterations permit
# 2  201507161644            3  additions alterations or repairs
# 3  201610049499            8            otc alterations permit
# 4       M470307            8            otc alterations permit
#
#   Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 0           03/08/2017  3522   116              9                  NaN
# 1           02/21/2017  3970   005            405                  NaN
# 2           07/16/2015  0670   011           1238                  NaN
# 3           10/04/2016  2024   026           1830                  NaN
# 4           03/12/2014  0529  018C           2844                  NaN
#
#   Street Name Street Suffix      ...        Existing Construction Type  \
# 0     Bernice            St      ...                               NaN
# ...

# %%
pd.options.display.max_columns = 50
df.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0       M766848            8            otc alterations permit
# 1       M762447            8            otc alterations permit
# 2  201507161644            3  additions alterations or repairs
# 3  201610049499            8            otc alterations permit
# 4       M470307            8            otc alterations permit
#
#   Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 0           03/08/2017  3522   116              9                  NaN
# 1           02/21/2017  3970   005            405                  NaN
# 2           07/16/2015  0670   011           1238                  NaN
# 3           10/04/2016  2024   026           1830                  NaN
# 4           03/12/2014  0529  018C           2844                  NaN
#
#   Street Name Street Suffix  Unit Unit Suffix  \
# 0     Bernice            St   NaN         NaN
# 1     Florida            St   NaN         NaN
# ...

# %%
# df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 9970    False
# 9971    False
# 9972    False
# 9973    False
# 9974    False
# 9975    False
# 9976    False
# 9977    False
# 9978    False
# 9979    False
# 9980    False
# 9981    False
# 9982    False
# 9983    False
# 9984    False
# 9985    False
# 9986    False
# 9987    False
# 9988    False
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# 9994    False
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# ...

# %%
# Exact instance duplicated?
df.duplicated().sum()
# Out:
# 0

# %%
# Individual column
df.duplicated(subset='Permit Number').sum()
# Out:
# 62

# %%
df['Permit Number'].value_counts()
# Out:
# 201602179765    6
# 201503302197    3
# 201503302201    2
# 201706149373    2
# 201409186670    2
# M554787         2
# M875227         2
# M875407         2
# 201406249251    2
# 201602189896    2
# 201504143628    2
# 201403039716    2
# 201305287964    2
# 201607051549    2
# 201709016761    2
# 201405155817    2
# 201406198850    2
# 201605238127    2
# M468327         2
# 201511102210    2
# 201411181828    2
# 201602179758    2
# 201708175092    2
# 201506229578    2
# 201504153685    2
# 201504294940    2
# 201711133835    2
# 201512145046    2
# 201607202893    2
# 201401236957    2
#                ..
# 201307313253    1
# 201710110938    1
# 201612306355    1
# 201309066104    1
# 201509046272    1
# 201608034050    1
# 201706169615    1
# M545087         1
# 201310078648    1
# 201312184469    1
# 201510301228    1
# M473948         1
# 201407151284    1
# 201611072086    1
# M682909         1
# 201310098904    1
# 201706068559    1
# 201610190665    1
# 201303283248    1
# ...

# %%
df['Permit Number'].value_counts().nlargest(1)
# Out:
# 201602179765    6
# Name: Permit Number, dtype: int64

# %%
# DFobject[condition]
# Here condition --> DFobject["Column Name"] == <a_legit_value>
df[df['Permit Number'] == '201602179765']
# Out:
#      Permit Number  Permit Type            Permit Type Definition  \
# 1237  201602179765            3  additions alterations or repairs
# 1682  201602179765            3  additions alterations or repairs
# 1881  201602179765            3  additions alterations or repairs
# 2222  201602179765            3  additions alterations or repairs
# 4417  201602179765            3  additions alterations or repairs
# 8825  201602179765            3  additions alterations or repairs
#
#      Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 1237           02/17/2016  4734  002           1108                  NaN
# 1682           02/17/2016  4734  002           1029                  NaN
# 1881           02/17/2016  4734  002           1071                  NaN
# 2222           02/17/2016  4734  002           1073                  NaN
# 4417           02/17/2016  4734  002           1183                  NaN
# ...

# %%
# DFobject.loc[condition, <single_column_name_or_a_list_of_columns>]
df.loc[df['Permit Number'] == '201602179765', ['Permit Number', 'Permit Creation Date']]
# Out:
#      Permit Number Permit Creation Date
# 1237  201602179765           02/17/2016
# 1682  201602179765           02/17/2016
# 1881  201602179765           02/17/2016
# 2222  201602179765           02/17/2016
# 4417  201602179765           02/17/2016
# 8825  201602179765           02/17/2016

# %%
temp = df.drop_duplicates(subset='Permit Number', keep='first')
temp.shape
# Out:
# (9938, 43)

# %%
temp[temp['Permit Number'] == '201602179765']
# Out:
#      Permit Number  Permit Type            Permit Type Definition  \
# 1237  201602179765            3  additions alterations or repairs
#
#      Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 1237           02/17/2016  4734  002           1108                  NaN
#
#      Street Name Street Suffix  Unit Unit Suffix  \
# 1237       Palou            Av   NaN         NaN
#
#                                             Description Current Status  \
# 1237  provide a new sprinklers monitoring system, wa...      withdrawn
#
#      Current Status Date  Filed Date Issued Date Completed Date  \
# 1237          06/22/2016  02/17/2016         NaN            NaN
#
#      First Construction Document Date Structural Notification  \
# 1237                              NaN                     NaN
#
#       Number of Existing Stories  Number of Proposed Stories  \
# 1237                         2.0                         2.0
#
# ...

# %%
temp = df.drop_duplicates(subset='Permit Number', keep='last')
temp.shape
# Out:
# (9938, 43)

# %%
temp[temp['Permit Number'] == '201602179765']
# Out:
#      Permit Number  Permit Type            Permit Type Definition  \
# 8825  201602179765            3  additions alterations or repairs
#
#      Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 8825           02/17/2016  4734  002           1124                  NaN
#
#      Street Name Street Suffix  Unit Unit Suffix  \
# 8825       Palou            Av   NaN         NaN
#
#                                             Description Current Status  \
# 8825  provide a new sprinklers monitoring system, wa...      withdrawn
#
#      Current Status Date  Filed Date Issued Date Completed Date  \
# 8825          06/22/2016  02/17/2016         NaN            NaN
#
#      First Construction Document Date Structural Notification  \
# 8825                              NaN                     NaN
#
#       Number of Existing Stories  Number of Proposed Stories  \
# 8825                         2.0                         2.0
#
# ...

# %%
temp = df.drop_duplicates(subset='Permit Number', keep=False)
temp.shape
# Out:
# (9881, 43)

# %%
temp[temp['Permit Number'] == '201602179765']
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []

# %%
# delete an object
del temp

# %%
# Multi-level keys
df.duplicated(subset=['Permit Number', 'Record ID']).sum()
# Out:
# 0

# %%
df.isna()
# Out:
#       Permit Number  Permit Type  Permit Type Definition  \
# 0             False        False                   False
# 1             False        False                   False
# 2             False        False                   False
# 3             False        False                   False
# 4             False        False                   False
# 5             False        False                   False
# 6             False        False                   False
# 7             False        False                   False
# 8             False        False                   False
# 9             False        False                   False
# 10            False        False                   False
# 11            False        False                   False
# 12            False        False                   False
# 13            False        False                   False
# 14            False        False                   False
# ...

# %%
df.isna().sum(axis=0)
# Out:
# Permit Number                                 0
# Permit Type                                   0
# Permit Type Definition                        0
# Permit Creation Date                          0
# Block                                         0
# Lot                                           0
# Street Number                                 0
# Street Number Suffix                       9901
# Street Name                                   0
# Street Suffix                               151
# Unit                                       8502
# Unit Suffix                                9904
# Description                                  10
# Current Status                                0
# Current Status Date                           0
# Filed Date                                    0
# Issued Date                                 753
# Completed Date                             5119
# First Construction Document Date            752
# Structural Notification                    9657
# ...

# %%
df.isna().sum(axis=1)
# Out:
# 0       22
# 1       26
# 2        7
# 3        8
# 4       22
# 5       10
# 6        8
# 7        9
# 8        8
# 9        8
# 10       7
# 11       7
# 12       9
# 13       7
# 14       9
# 15       7
# 16      11
# 17      22
# 18       8
# 19      16
# 20      12
# 21       9
# 22       8
# 23      22
# 24       7
# 25       7
# 26       8
# 27      12
# 28       8
# 29       7
#         ..
# 9970     9
# 9971     9
# 9972     8
# 9973     8
# 9974     8
# 9975     8
# 9976     8
# 9977    17
# 9978    13
# 9979    12
# 9980     8
# 9981    11
# 9982    22
# 9983     8
# 9984     7
# 9985    22
# 9986     7
# 9987    15
# 9988    12
# 9989     9
# 9990     9
# 9991    22
# 9992     8
# 9993    22
# 9994    12
# 9995     8
# 9996     7
# 9997    11
# 9998     8
# 9999     6
# Length: 10000, dtype: int64

# %%
df.isna().sum(axis=1).max()
# Out:
# 28

# %%
df.isna().sum(axis=1).idxmax() # alt. argmax()
# Out:
# 8840

# %%
# DFobject.iloc[<single_index_value_or_a_range>]
df.iloc[5:8]
# Out:
#   Permit Number  Permit Type  Permit Type Definition Permit Creation Date  \
# 5  201306078967            8  otc alterations permit           06/07/2013
# 6  201610241010            8  otc alterations permit           10/24/2016
# 7  201706280569            8  otc alterations permit           06/28/2017
#
#   Block  Lot  Street Number Street Number Suffix Street Name Street Suffix  \
# 5  0595  002           1604                  NaN     Jackson            St
# 6  5839  017            225                  NaN    Genebern            Wy
# 7  2842  010            275                  NaN     Olympia            Wy
#
#    Unit Unit Suffix                                        Description  \
# 5   NaN         NaN  shoring revision to issued pa# 201208086865.  ...
# 6   NaN         NaN                     replace 120 sf slab at garage.
# 7   NaN         NaN  removal o f not applicable special inspections...
#
#   Current Status Current Status Date  Filed Date Issued Date Completed Date  \
# ...

# %%
# DFobject.loc[<single_index_value_or_a_range>,<single_column_name_or_list_of_column_names>]
df.loc[5:8, 'Permit Number']
# Out:
# 5    201306078967
# 6    201610241010
# 7    201706280569
# 8    201702028538
# Name: Permit Number, dtype: object

# %%
df.iloc[8840]
# Out:
# Permit Number                                                                  201712206994
# Permit Type                                                                               8
# Permit Type Definition                                               otc alterations permit
# Permit Creation Date                                                             12/20/2017
# Block                                                                                  3541
# Lot                                                                                     160
# Street Number                                                                           841
# Street Number Suffix                                                                    NaN
# Street Name                                                                            14th
# Street Suffix                                                                            St
# ...

# %%
# DFobject.iloc[<single_index_value_or_a_range>]
df.iloc[8840].to_frame().T
# Out:
#      Permit Number Permit Type  Permit Type Definition Permit Creation Date  \
# 8840  201712206994           8  otc alterations permit           12/20/2017
#
#      Block  Lot Street Number Street Number Suffix Street Name Street Suffix  \
# 8840  3541  160           841                  NaN        14th            St
#
#      Unit Unit Suffix                                        Description  \
# 8840  NaN         NaN  revision to 201710252232 new fire rated clears...
#
#      Current Status Current Status Date  Filed Date Issued Date  \
# 8840          filed          12/20/2017  12/20/2017         NaN
#
#      Completed Date First Construction Document Date Structural Notification  \
# 8840            NaN                              NaN                     NaN
#
#      Number of Existing Stories Number of Proposed Stories  \
# 8840                        NaN                        NaN
#
#      Voluntary Soft-Story Retrofit Fire Only Permit Permit Expiration Date  \
# ...

# %%
temp2 = df.dropna(subset=None, axis=1, how='any', thresh=None)
temp2.shape
# Out:
# (10000, 12)

# %%
temp2 = df.dropna(subset=None, axis=1, how='any', thresh=5000)
temp2.shape
# Out:
# (10000, 34)

# %%
temp2 = df.dropna(subset=None, axis=1, how='all', thresh=None)
temp2.shape
# Out:
# (10000, 42)

# %%
temp2 = df.dropna(subset=None, axis=0, how='any', thresh=None)
temp2.shape
# Out:
# (0, 43)

# %%
temp2 = df.dropna(subset=['Estimated Cost', 'Revised Cost'], axis=0, how='any', thresh=None)
temp2.shape
# Out:
# (7829, 43)
